# %%
import pandas as pd
df = pd.read_json("./offcampushousing.JSON")

# %%
df["price"]
# Out:
# 0        965.0
# 1        965.0
# 2        965.0
# 3        965.0
# 4       1659.0
#          ...
# 2518     879.5
# 2519     879.5
# 2520     879.5
# 2521     879.5
# 2522     879.5
# Name: price, Length: 2523, dtype: float64

# %%
less_than_900 = df[df["price"] < 850]
between_700_and_900 = less_than_900[less_than_900["price"] > 800]
between_700_and_900
# Out:
#                                              address  price  bed  bath  area  \
# 211               205 S State St Ann Arbor, MI 48104  845.0    2   1.0  None
# 909    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 910    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 911    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 912    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 913    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 914    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 915    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 916    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 917    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# 918    402 East Jefferson Street Ann Arbor, MI 48104  830.0    8   4.0  2800
# ...
