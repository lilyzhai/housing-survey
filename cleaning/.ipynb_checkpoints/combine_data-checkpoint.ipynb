# %%
import numpy as np
import pandas as pd
import math

# %%
df1 = pd.read_json('../data/craigslist.json')
df2 = pd.read_json('../data/apartments.json')
df3 = pd.read_json('../data/showmetherent.json')
df4 = pd.read_json('../data/offcampushousing.json')

# %%
combine_df = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)
combine_df
# Out:
#                                      address   price bed  bath  area company  \
# 0                       3050 Birch Hollow Dr  1095.0   2   1.0   876    None
# 1                               912 Rose Ave  2000.0   4   2.5  2000    None
# 2                                       None   695.0   3   2.0     0    None
# 3       1505 Natalie Lane near Kipling Drive  1385.0   1   1.0   800    None
# 4       1505 Natalie Lane near Kipling Drive  1185.0   1   1.0   800    None
# ...                                      ...     ...  ..   ...   ...     ...
# 9369  1500 Gilbert Court Ann Arbor, MI 48105   879.5  10  10.0   130    None
# 9370  1500 Gilbert Court Ann Arbor, MI 48105   879.5  10  10.0   130    None
# 9371  1500 Gilbert Court Ann Arbor, MI 48105   879.5  10  10.0   130    None
# 9372  1500 Gilbert Court Ann Arbor, MI 48105   879.5  10  10.0   130    None
# 9373  1500 Gilbert Court Ann Arbor, MI 48105   879.5  10  10.0   130    None
#
# ...

# %%
combine_df.to_json(r'../data/cleaned_data/aggregated.json')
