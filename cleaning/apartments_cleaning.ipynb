# %%
import numpy as np
import pandas as pd
import re
import json

# %%
df = pd.read_json('../collection/raw_data/apartments.json')
df = df.drop(['recurring_fees', 'one_time_fees'], axis=1)
col = ['address', 'price', 'bed', 'bath', 'area', 'company', 'neighborhood', 'laundry', 'pets', 'parking', 'utilities', 'property_type', 'year_built', 'description', 'images']
df.iloc[1]
# Out:
# address                                         1777 Plymouth Rd
# company                                                     None
# price                                                   [$1,625]
# bed                                                       [1 BR]
# bath                                                      [1 BA]
# area                                                 [730 Sq Ft]
# description    Immediate occupancy! Unique opportunity to liv...
# rating                                                       NaN
# amenities                                                     []
# Name: 1, dtype: object

# %%
final_rows = []
for row in df.itertuples():
    address = row[1]
    company = row[2]
    description = row[7]
    rating = row[8]
    amenities = row[9]
    
    for j, s in enumerate(row[3]):
        entry = {'address': address,
                 'company': company, 
                 'price': row[3][j],
                 'bed': row[4][j],
                 'bath': row[5][j],
                 'area': row[6][j],
                 'description': description,
                 'rating': rating,
                 'amenities': amenities
                }
        final_rows.append(entry)

# %%
# extract single rows and clean them
final_rows = pd.DataFrame(final_rows)

# %%
final_rows.iloc[0:50]
# Out:
#                                           address                     company  \
# 0                               2709 N Spurway Dr                        None
# 1                                1777 Plymouth Rd                        None
# 2                                    908 Sybil St                        None
# 3                                  333 Packard St                        None
# 4                                   513 Krause St                        None
# 5                       555 E William St Unit 10E                        None
# 6                             2918 Signature Blvd                        None
# 7                                3447 Cummings Dr                        None
# 8                            City Place Ann Arbor  Campus Village Communities
# 9                            City Place Ann Arbor  Campus Village Communities
# 10                           City Place Ann Arbor  Campus Village Communities
# 11                           City Place Ann Arbor  Campus Village Communities
# 12                           City Place Ann Arbor  Campus Village Communities
# 13                           City Place Ann Arbor  Campus Village Communities
# 14                           City Place Ann Arbor  Campus Village Communities
# 15                                306 Thompson St                        None
# 16                                  536 S 4th Ave                        None
# 17                                  536 S 4th Ave                        None
# 18                                  536 S 4th Ave                        None
# 19                                  536 S 4th Ave                        None
# 20                                  536 S 4th Ave                        None
# 21                                  536 S 4th Ave                        None
# 22                              722 E Kingsley St                        None
# 23                                 736 Packard St                        None
# 24   Studio, 1 bath Apartment - 1352 Wilmot Ct #1                        None
# 25  3 br, 1 bath Triplex - 1003 Packard St Unit A                        None
# 26                               411 N Ingalls St                        None
# 27                                111 N Ashley St                        None
# 28    1 br, 1 bath House - 1309 S State St Unit 5                        None
# 29                                1103 W Huron St                        None
# 30                               919 Addington Ln                        None
# 31                               701 Catherine St                        None
# 32  1 br, 1 bath House - 311 1/2 S 5th Ave Unit 1                        None
# 33                                 1015 Church St                        None
# 34                                  524 S 4th Ave                        None
# 35                          2041-2047 Jackson Ave                        None
# 36                                  645 N 4th Ave                        None
# 37    Studio, 1 bath House - 804 Monroe St Apt #3                        None
# 38        5 br, 3.5 bath House - 502 Catherine St                        None
# 39  1 br, 1 bath House - 1303 Granger Ave # 5 # 5                        None
# 40                                 1321 Wilmot St                        None
# 41                               1039 Baldwin Ave                        None
# 42   1 br, 1 bath Apartment - 732 S Forest Ave #5                        None
# 43                          1619 S University Ave                        None
# 44                        Pheasant Run Apartments       Hartman & Tyner, Inc.
# 45                        Pheasant Run Apartments       Hartman & Tyner, Inc.
# 46                        Pheasant Run Apartments       Hartman & Tyner, Inc.
# 47                        Pheasant Run Apartments       Hartman & Tyner, Inc.
# 48                                111 N Ashley St                        None
# 49                            604 W Washington St                        None
#
#                                price     bed    bath         area  \
# 0                             $3,300   3 BRs  2½ BAs  2,438 Sq Ft
# 1                             $1,625    1 BR    1 BA    730 Sq Ft
# 2                             $1,625   2 BRs    1 BA
# 3                             $1,075    1 BR    1 BA    375 Sq Ft
# 4                             $1,900    1 BR    1 BA    900 Sq Ft
# 5                             $1,500  Studio    1 BA    400 Sq Ft
# 6                             $1,900   2 BRs   2 BAs  1,400 Sq Ft
# 7                               $700    1 BR    1 BA
# 8           $920\r\n\t\t\t\t/ Person   6 BRs   5 BAs  2,267 Sq Ft
# 9           $970\r\n\t\t\t\t/ Person   6 BRs   5 BAs  2,267 Sq Ft
# 10          $975\r\n\t\t\t\t/ Person   6 BRs   6 BAs  2,665 Sq Ft
# 11  $975 - 1,060\r\n\t\t\t\t/ Person   6 BRs   6 BAs  2,665 Sq Ft
# 12        $1,060\r\n\t\t\t\t/ Person   6 BRs   6 BAs  2,616 Sq Ft
# 13        $1,080\r\n\t\t\t\t/ Person   6 BRs   6 BAs  2,616 Sq Ft
# 14        $1,185\r\n\t\t\t\t/ Person   6 BRs   5 BAs  2,267 Sq Ft
# 15                              $935  Studio    1 BA
# 16                            $1,095  Studio    1 BA    550 Sq Ft
# 17                            $1,425   2 BRs    1 BA    800 Sq Ft
# 18                            $1,895   2 BRs    1 BA    750 Sq Ft
# 19                            $1,095  Studio    1 BA    550 Sq Ft
# 20                            $1,425   2 BRs    1 BA    800 Sq Ft
# 21                            $1,895   2 BRs    1 BA    750 Sq Ft
# 22                            $4,650   6 BRs   2 BAs
# 23                            $1,050  Studio    1 BA
# 24                              $925  Studio    1 BA
# 25                            $2,100   3 BRs    1 BA
# 26                            $3,950   5 BRs   2 BAs  1,060 Sq Ft
# 27                            $2,200    1 BR  1½ BAs    863 Sq Ft
# 28                            $1,055    1 BR    1 BA
# 29                            $1,365   2 BRs    1 BA    800 Sq Ft
# 30                            $1,650   2 BRs   2 BAs  1,335 Sq Ft
# 31                            $5,750   6 BRs   2 BAs  2,000 Sq Ft
# 32                            $1,195    1 BR    1 BA
# 33                            $1,095    1 BR    1 BA    650 Sq Ft
# 34                            $3,600   5 BRs   2 BAs
# 35                            $1,150   2 BRs    1 BA    820 Sq Ft
# 36                            $2,195   2 BRs  1½ BAs
# 37                              $880  Studio    1 BA    250 Sq Ft
# 38                            $4,900   5 BRs  3½ BAs
# 39                            $1,330    1 BR    1 BA
# 40                            $1,140    1 BR    1 BA
# 41                              $700    1 BR   2 BAs
# 42                            $1,105    1 BR    1 BA
# 43                            $7,900   9 BRs   3 BAs
# 44                              $870    1 BR    1 BA    750 Sq Ft
# 45                              $995   2 BRs    1 BA    900 Sq Ft
# 46                              $870    1 BR    1 BA    750 Sq Ft
# 47                              $995   2 BRs    1 BA    900 Sq Ft
# 48                            $2,600    1 BR    1 BA    922 Sq Ft
# 49                            $1,075    1 BR    1 BA    460 Sq Ft
#
#                                           description  rating  \
# 0   BRAND NEW! This North Oaks luxury townhome on ...     NaN
# 1   Immediate occupancy! Unique opportunity to liv...     NaN
# 2   (734) 680-8673 - This is a great building loca...     NaN
# 3   (734) 996-1991 - Four 1 Bedroom Apartment in b...     NaN
# 4   (734) 255-1299 - PRICE LOWERED! Old West Side ...     NaN
# 5   Renovated 10th floor furnished highrise condo,...     NaN
# 6   ** FOR RENT ** Location, Location, Location! 2...     NaN
# 7   (734) 709-5709 - Furnished bedrooms available ...     NaN
# 8   City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 9   City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 10  City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 11  City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 12  City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 13  City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 14  City Place Ann Arbor offers 6 bedroom townhome...     5.0
# 15  (734) 996-2836 - Five (5) apartments in downto...     NaN
# 16  Discover your new apartment at 536 S 4th Ave i...     4.0
# 17  Discover your new apartment at 536 S 4th Ave i...     4.0
# 18  Discover your new apartment at 536 S 4th Ave i...     4.0
# 19  Discover your new apartment at 536 S 4th Ave i...     4.0
# 20  Discover your new apartment at 536 S 4th Ave i...     4.0
# 21  Discover your new apartment at 536 S 4th Ave i...     4.0
# 22  (734) 996-1991 - WOW LOOK AT THIS A BEAUTIFUL ...     NaN
# 23  (734) 680-6727 - A short, 5-minute walk to Ros...     NaN
# 24  (734) 996-2836 - Three (3) apartments in build...     NaN
# 25  (734) 203-7600 - 1003 Packard is a beautiful, ...     NaN
# 26  (734) 662-8832 - Vintage converted house with ...     NaN
# 27  6 month Lease.  Highly Sought After Ashley Ter...     NaN
# 28  (734) 680-6727 - Steps from University of Mich...     NaN
# 29  (734) 726-0357 - Quality 2-Bedroom Apartment i...     NaN
# 30  Spotless entry level ranch with 2 bedrooms and...     NaN
# 31  Charming 6 bedroom, 2 bathroom house in the he...     NaN
# 32  (734) 680-6727 - If you love downtown living t...     NaN
# 33  (734) 663-4101 - An attractive brick and cedar...     NaN
# 34  Located on South 4th between Packard and Madis...     NaN
# 35  (734) 662-5500 - Jackson West Apartments ****S...     NaN
# 36  (734) 657-2096 - Unique/Fantastic opportunity....     NaN
# 37  (734) 996-1991 - 7 Total Units. Limited Parkin...     NaN
# 38  (734) 203-7600 - 502 Catherine is a spacious h...     NaN
# 39  (734) 260-7215 - Available, Fall to Fall lease...     NaN
# 40  (734) 996-1991 - 9 unit apartment building wit...     NaN
# 41  (734) 668-1100 - Room Available in a Charming ...     NaN
# 42  (734) 996-2836 - Classy brick house w/Californ...     NaN
# 43  (734) 995-9200 - Nine bedroom furnished house ...     NaN
# 44  A great location and a wonderful home await yo...     3.7
# 45  A great location and a wonderful home await yo...     3.7
# 46  A great location and a wonderful home await yo...     3.7
# 47  A great location and a wonderful home await yo...     3.7
# 48  Beautiful downtown, 6th floor, one bedroom, on...     NaN
# 49  (734) 996-1991 - Two One Bedroom Apartments. D...     NaN
#
#                                             amenities
# 0          [{'Unique Features': ['NewConstruction']}]
# 1                                                  []
# 2   [{'Unique Features': ['No Pets Allowed, Applia...
# 3   [{'Unique Features': ['Cats Allowed - $100 Non...
# 4   [{'Unique Features': ['Lease Lengths - Contact...
# 5   [{'Pet Policy': []}, {'Parking': []}, {'Proper...
# 6                                                  []
# 7   [{'Pet Policy': []}, {'Property Information': ...
# 8   [{'Unique Features': ['16' Vaulted Ceiling', '...
# 9   [{'Unique Features': ['16' Vaulted Ceiling', '...
# 10  [{'Unique Features': ['16' Vaulted Ceiling', '...
# 11  [{'Unique Features': ['16' Vaulted Ceiling', '...
# 12  [{'Unique Features': ['16' Vaulted Ceiling', '...
# 13  [{'Unique Features': ['16' Vaulted Ceiling', '...
# 14  [{'Unique Features': ['16' Vaulted Ceiling', '...
# 15  [{'Unique Features': ['No Pets Allowed, Oven, ...
# 16  [{'Property Information': ['Built in 1957', '6...
# 17  [{'Property Information': ['Built in 1957', '6...
# 18  [{'Property Information': ['Built in 1957', '6...
# 19  [{'Property Information': ['Built in 1957', '6...
# 20  [{'Property Information': ['Built in 1957', '6...
# 21  [{'Property Information': ['Built in 1957', '6...
# 22  [{'Unique Features': ['No Pets Allowed, Oven']...
# 23  [{'Pet Policy': []}, {'Property Information': ...
# 24  [{'Unique Features': ['No Pets Allowed, Oven, ...
# 25  [{'Unique Features': ['No Pets Allowed, Oven, ...
# 26  [{'Unique Features': ['No Pets Allowed - No Ex...
# 27                                                 []
# 28                               [{'Pet Policy': []}]
# 29  [{'Unique Features': ['No Dogs Allowed, Lease ...
# 30                                                 []
# 31  [{'Parking': []}, {'Lease Length': ['12 Months...
# 32  [{'Pet Policy': []}, {'Features': ['Air Condit...
# 33  [{'Unique Features': ['No Pets Allowed, Lease ...
# 34             [{'Services': ['Laundry Facilities']}]
# 35  [{'Unique Features': ['No Dogs Allowed']}, {'P...
# 36  [{'Unique Features': ['No Pets Allowed, High-S...
# 37  [{'Unique Features': ['Cats Allowed - $100 Non...
# 38  [{'Unique Features': ['Oven, High-Speed Intern...
# 39  [{'Unique Features': ['Small Dogs Allowed - $1...
# 40  [{'Unique Features': ['Utilities - Wireless In...
# 41                                                 []
# 42  [{'Unique Features': ['No Pets Allowed, Oven, ...
# 43                                                 []
# 44  [{'Unique Features': ['Newly Modernized Outdoo...
# 45  [{'Unique Features': ['Newly Modernized Outdoo...
# 46  [{'Unique Features': ['Newly Modernized Outdoo...
# 47  [{'Unique Features': ['Newly Modernized Outdoo...
# 48                                                 []
# 49  [{'Unique Features': ['Small Dogs Allowed - $2...

# %%
def clean_bed(bed):  
    if 'Studio' not in bed:
        bed = bed[:-3]
    else:
        bed = 0
    return bed

final_rows['bed'] = final_rows['bed'].apply(clean_bed)

# %%
def clean_bath(room):
    room = room[:-3]
    if '½' in room:
        room = float(room[0] + '.5')
    else:
        room = float(room)
    return room

final_rows['bath'] = final_rows['bath'].apply(clean_bath)

# %%
def clean_area(room):
    room = room[:-5]
    if room != '':
        if len(room) < 7:
            return float(room.replace(',', ''))
        else:
            # mean recorded if price range given
            var = lambda x: (int(x[:x.find('-')].replace(',', '')) + int(x[x.find('-') + 1:].replace(',', ''))) / 2 
            return float(var(room))   
    else:
        return np.nan

final_rows['area'] = final_rows['area'].apply(clean_area)

# %%
def clean_price(price):
    price = price.replace(',', '').replace('Person', '').replace('$', '').replace('/', '').strip()
    if len(price) < 7:
        return float(price)
    elif re.search('[Cc]all for [Rr]ent', price) != None:
        return np.nan
    else:
        # mean recorded if price range given
        var = lambda x: (int(x[:x.find('-')].replace(',', '')) + int(x[x.find('-') + 1:].replace(',', ''))) / 2 
        return float(var(price))

final_rows['price'] = final_rows['price'].apply(clean_price)

# %%
final_rows
# Out:
#                 address company   price bed  bath    area  \
# 0     2709 N Spurway Dr    None  3300.0  3    2.5  2438.0
# 1      1777 Plymouth Rd    None  1625.0   1   1.0   730.0
# 2          908 Sybil St    None  1625.0  2    1.0     NaN
# 3        333 Packard St    None  1075.0   1   1.0   375.0
# 4         513 Krause St    None  1900.0   1   1.0   900.0
# ...                 ...     ...     ...  ..   ...     ...
# 1784    3210 Mc Comb St    None  1500.0  3    1.0   988.0
# 1785     1127 Church St    None  2050.0  2    1.0     NaN
# 1786     1901 S Zeeb Rd    None  1800.0  4    1.0  2012.0
# 1787       616 Susan Dr    None  2000.0  3    2.0  1008.0
# 1788     2425 Foxway Dr    None  2800.0  4    3.5  2972.0
#
#                                             description  rating  \
# 0     BRAND NEW! This North Oaks luxury townhome on ...     NaN
# 1     Immediate occupancy! Unique opportunity to liv...     NaN
# 2     (734) 680-8673 - This is a great building loca...     NaN
# 3     (734) 996-1991 - Four 1 Bedroom Apartment in b...     NaN
# 4     (734) 255-1299 - PRICE LOWERED! Old West Side ...     NaN
# ...                                                 ...     ...
# 1784  Very nice three bedroom, one bathroom ranch wi...     NaN
# 1785  (734) 662-8832 - AUGUST:  Two wonderful 2 bedr...     NaN
# 1786  This historic farmhouse with beautiful views i...     NaN
# 1787  Lovely ranch home available for rent August 15...     NaN
# 1788  A very unique opportunity in the popular Foxfi...     NaN
#
#                                               amenities
# 0            [{'Unique Features': ['NewConstruction']}]
# 1                                                    []
# 2     [{'Unique Features': ['No Pets Allowed, Applia...
# 3     [{'Unique Features': ['Cats Allowed - $100 Non...
# 4     [{'Unique Features': ['Lease Lengths - Contact...
# ...                                                 ...
# 1784                                                 []
# 1785  [{'Unique Features': ['No Pets Allowed, Oven']...
# 1786                                                 []
# 1787  [{'Pet Policy': []}, {'Features': ['Washer/Dry...
# 1788                                                 []
#
# [1789 rows x 9 columns]

# %%
pets, laundry, parking, property_type, year_built, neighborhood, utilities, images = [], [], [], [], [], [], [], []
amenities = final_rows['amenities']
for row in amenities.values:
    row = json.dumps(row)
    
    if re.search('(?<!No )Cats Allowed|(?<!No )Dogs Allowed|considered', row) != None:
        pets.append(1)
    else: 
        pets.append(0)
        
    if re.search('[Ll]aundry|Washer|Dryer', row) != None:
        laundry.append(1)
    else:
        laundry.append(0)
    
    if re.search('parking', row) != None:
        parking.append(1)
    else:
        parking.append(0)
    
    year = re.search('Built in (\d*)', row)
    if year != None:
        year_built.append(year.group(1))
    else:
        year_built.append(np.nan)
        
    property_type.append('apartment')
    neighborhood.append(None)
    utilities.append([])
    images.append([])

# %%
final_rows['pets'] = pets
final_rows['laundry'] = laundry
final_rows['parking'] = parking
final_rows['year_built'] = year_built
final_rows['property_type'] = property_type
final_rows['neighborhood'] = neighborhood
final_rows['utilities'] = utilities
final_rows['images'] = images

final_rows = final_rows[col]

# %%
final_rows
# Out:
#                 address   price bed  bath    area company neighborhood  \
# 0     2709 N Spurway Dr  3300.0  3    2.5  2438.0    None         None
# 1      1777 Plymouth Rd  1625.0   1   1.0   730.0    None         None
# 2          908 Sybil St  1625.0  2    1.0     NaN    None         None
# 3        333 Packard St  1075.0   1   1.0   375.0    None         None
# 4         513 Krause St  1900.0   1   1.0   900.0    None         None
# ...                 ...     ...  ..   ...     ...     ...          ...
# 1784    3210 Mc Comb St  1500.0  3    1.0   988.0    None         None
# 1785     1127 Church St  2050.0  2    1.0     NaN    None         None
# 1786     1901 S Zeeb Rd  1800.0  4    1.0  2012.0    None         None
# 1787       616 Susan Dr  2000.0  3    2.0  1008.0    None         None
# 1788     2425 Foxway Dr  2800.0  4    3.5  2972.0    None         None
#
#       laundry  pets  parking utilities property_type year_built  \
# 0           0     0        0        []     apartment        NaN
# 1           0     0        0        []     apartment        NaN
# 2           1     0        0        []     apartment        NaN
# 3           1     1        0        []     apartment        NaN
# 4           1     0        0        []     apartment        NaN
# ...       ...   ...      ...       ...           ...        ...
# 1784        0     0        0        []     apartment        NaN
# 1785        1     0        0        []     apartment        NaN
# 1786        0     0        0        []     apartment        NaN
# 1787        1     0        0        []     apartment        NaN
# 1788        0     0        0        []     apartment        NaN
#
#                                             description images
# 0     BRAND NEW! This North Oaks luxury townhome on ...     []
# 1     Immediate occupancy! Unique opportunity to liv...     []
# 2     (734) 680-8673 - This is a great building loca...     []
# 3     (734) 996-1991 - Four 1 Bedroom Apartment in b...     []
# 4     (734) 255-1299 - PRICE LOWERED! Old West Side ...     []
# ...                                                 ...    ...
# 1784  Very nice three bedroom, one bathroom ranch wi...     []
# 1785  (734) 662-8832 - AUGUST:  Two wonderful 2 bedr...     []
# 1786  This historic farmhouse with beautiful views i...     []
# 1787  Lovely ranch home available for rent August 15...     []
# 1788  A very unique opportunity in the popular Foxfi...     []
#
# [1789 rows x 15 columns]

# %%
final_rows.to_json(r'../data/apartments.json')
