# %%
import numpy as np
import pandas as pd
import re
import json

# %%
df = pd.read_json('../collection/raw_data/apartments.json')

# %%
df.head()
# Out:
#              address company     price      bed      bath           area  \
# 0  2709 N Spurway Dr    None  [$3,300]  [3 BRs]  [2½ BAs]  [2,438 Sq Ft]
# 1   1777 Plymouth Rd    None  [$1,625]   [1 BR]    [1 BA]    [730 Sq Ft]
# 2       908 Sybil St    None  [$1,625]  [2 BRs]    [1 BA]             []
# 3     333 Packard St    None  [$1,075]   [1 BR]    [1 BA]    [375 Sq Ft]
# 4      513 Krause St    None  [$1,900]   [1 BR]    [1 BA]    [900 Sq Ft]
#
#                                          description recurring_fees  \
# 0  BRAND NEW! This North Oaks luxury townhome on ...             []
# 1  Immediate occupancy! Unique opportunity to liv...             []
# 2  (734) 680-8673 - This is a great building loca...             []
# 3  (734) 996-1991 - Four 1 Bedroom Apartment in b...             []
# 4  (734) 255-1299 - PRICE LOWERED! Old West Side ...             []
#
#   one_time_fees  rating                                          amenities
# ...
