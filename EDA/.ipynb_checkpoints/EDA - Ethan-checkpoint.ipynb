# %%
import numpy as np
import pandas as pd
import re
import json
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib.mlab as mlab

# %%
df = pd.read_json('../data/apartments.json')

# %%
df.head()
# Out:
#                                        address   price  bed  bath    area  \
# 0                            2709 N Spurway Dr  3300.0    3   2.5  2438.0
# 1                             1777 Plymouth Rd  1625.0    1   1.0   730.0
# 10                        City Place Ann Arbor   975.0    6   6.0  2665.0
# 100   5 br, 2 bath House - 504 Lawrence St # 2  4000.0    5   2.0     NaN
# 1000                                The George  2619.0    2   2.0  1225.0
#
#                          company  neighborhood  laundry  pets  parking  \
# 0                           None           NaN        0     0        0
# 1                           None           NaN        0     0        0
# 10    Campus Village Communities           NaN        1     0        0
# 100                         None           NaN        1     1        0
# 1000          The Hayman Company           NaN        1     0        0
#
#      utilities property_type  year_built  \
# 0           []     apartment         NaN
# 1           []     apartment         NaN
# 10          []     apartment      2012.0
# 100         []     apartment         NaN
# 1000        []     apartment      2018.0
#
#                                             description images
# 0     BRAND NEW! This North Oaks luxury townhome on ...     []
# 1     Immediate occupancy! Unique opportunity to liv...     []
# 10    City Place Ann Arbor offers 6 bedroom townhome...     []
# 100   (734) 260-7215 - Available. Fall to Fall lease...     []
# 1000  Move now and receive January rent FREE on sele...     []

# %%
df.shape
# Out:
# (1789, 15)

# %%
df.columns
# Out:
# Index(['address', 'price', 'bed', 'bath', 'area', 'company', 'neighborhood',
#        'laundry', 'pets', 'parking', 'utilities', 'property_type',
#        'year_built', 'description', 'images'],
#       dtype='object')

# %%
x = "price"
y = "pets"
plt.scatter(df[x],df[y])
plt.xlabel(x)
plt.ylabel(y)
# Out:
# Text(0, 0.5, 'pets')

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.close()

# %%
df["company"].unique()
# Out:
# array([None, 'Campus Village Communities', 'The Hayman Company',
#        'FOURMIDABLE Real Estate Management', 'Wickfield Properties',
#        'York Properties, Inc.', 'Magar & Company', 'Asset Living',
#        'Huron Towers', 'Lightstone Group', 'Peak Management',
#        'Wilson White Company', 'SilverView Partners', 'Greystar',
#        'The Cabrio Group', 'Suburban Campus Properties, Inc.',
#        'Bleznak Real Estate Investment Group', 'Village Green',
#        'Jacobson Brothers', 'Slavik Management',
#        'Oakland Management Corp.', 'Reliance Capital Group',
#        'RAM Partners, LLC', 'McCormack Baron Salazar',
#        'Friedman Real Estate', 'LR Management',
#        'The Solomon Organization', 'Hartman & Tyner, Inc.',
#        'Allmand Properties', 'Stuart Frankel Development Co.',
#        'Campus Life & Style', 'Marquette Companies',
#        'The Habitat Company', 'Storypoint', 'The Tobin Group'],
#       dtype=object)

# %%
group = df.groupby("company").mean()

# %%
group.plot.bar(y=["price"])

# %%
plt.show()

# %%
craig = pd.read_json('../data/craigslist.json')

# %%
craig.describe()
# Out:
#               price          bed         bath         area  neighborhood  \
# count   2990.000000  2819.000000  2819.000000  2990.000000           0.0
# mean    1344.389298     1.875488     1.352430   785.572910           NaN
# std      728.873948     1.015371     0.562966   493.671424           NaN
# min        1.000000     0.000000     0.000000     0.000000           NaN
# 25%      979.000000     1.000000     1.000000   624.000000           NaN
# 50%     1199.000000     2.000000     1.000000   825.000000           NaN
# 75%     1499.000000     2.000000     2.000000  1000.000000           NaN
# max    15900.000000     8.000000     5.000000  8500.000000           NaN
#
#        laundry         pets      parking  year_built
# count   2990.0  2990.000000  2990.000000         0.0
# mean       1.0     0.852843     0.751839         NaN
# std        0.0     0.354322     0.432018         NaN
# min        1.0     0.000000     0.000000         NaN
# 25%        1.0     1.000000     1.000000         NaN
# 50%        1.0     1.000000     1.000000         NaN
# 75%        1.0     1.000000     1.000000         NaN
# max        1.0     1.000000     1.000000         NaN

# %%
n, bins, patches = plt.hist(craig["price"], bins=range(0,3000,10))

# %%
craig["price"].describe()
# Out:
# count     2990.000000
# mean      1344.389298
# std        728.873948
# min          1.000000
# 25%        979.000000
# 50%       1199.000000
# 75%       1499.000000
# max      15900.000000
# Name: price, dtype: float64

# %%
plt.close()

# %%
bins[list(n).index(n.max())]
# Out:
# 999

# %%
patches
# Out:
# <a list of 299 Patch objects>

# %%
import seaborn as sns

corr = df.corr()
ax = sns.heatmap(
    corr,

    vmin=-1, vmax=1, center=0,

    cmap=sns.diverging_palette(20, 220, n=200),

    square=True)

ax.set_xticklabels(

    ax.get_xticklabels(),

    rotation=45,

    horizontalalignment='right'

)
# Out:
# [Text(0.5, 0, 'price'),
#  Text(1.5, 0, 'bed'),
#  Text(2.5, 0, 'bath'),
#  Text(3.5, 0, 'area'),
#  Text(4.5, 0, 'neighborhood'),
#  Text(5.5, 0, 'laundry'),
#  Text(6.5, 0, 'pets'),
#  Text(7.5, 0, 'parking'),
#  Text(8.5, 0, 'year_built')]
