# %% [markdown]
# # Ann Arbor Housing Survey: Exploratory Data Analysis
# <hr>

# %%
# how do I install this?!
import dtale 
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import re
import json

# %%
df = pd.read_json('../data/cleaned_data/aggregated.json')
# a little look at the data
df.head()
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://DESKTOP-M2E0IMH:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df.describe()
# Out:
#               price          bed         bath         area      laundry  \
# count   7818.000000  8519.000000  9203.000000  5965.000000  7302.000000
# mean    1583.984971     2.094847     1.414919   978.319950     0.944399
# std     1095.510351     1.566232     0.782912   548.638798     0.229166
# min        1.000000     0.000000     0.000000     1.000000     0.000000
# 25%      989.000000     1.000000     1.000000   658.000000     1.000000
# 50%     1299.000000     2.000000     1.000000   888.000000     1.000000
# 75%     1725.000000     2.000000     2.000000  1100.000000     1.000000
# max    15900.000000    12.000000    10.000000  8500.000000     1.000000
#
#               pets      parking   year_built
# count  7302.000000  7302.000000  1766.000000
# mean      0.492468     0.644618  1974.872593
# std       0.499977     0.478662    34.674417
# min       0.000000     0.000000  1870.000000
# 25%       0.000000     0.000000  1964.000000
# 50%       0.000000     1.000000  1987.000000
# 75%       1.000000     1.000000  1998.000000
# max       1.000000     1.000000  2020.000000

# %% [markdown]
# ### Distribution of Price
#
# The first graph (excluding some very high outliers around 15000) shows a histogram and KDE of the overall price distribution. The second graph uses a log-linear scale and plots both the histogram and a rug plot to give a better impression of the actual price distribution; the plot shows characteristics of a long tail.

# %%
sns.set(style='darkgrid')
plt.subplots(2, 1, figsize=(7,7))
plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
plt.subplot(2, 1, 1)
ax1 = sns.distplot(df['price'], kde_kws={'bw':200, 'clip':[-1000, 10000]}, bins=32, color='#2ca02c')
plt.ticklabel_format(style='plain', axis='y')
plt.subplot(2, 1, 2)
ax2 = sns.distplot(df['price'], bins=32, color='#2ca02c', kde=False, rug=True)
ax2.set_yscale('log')
plt.savefig('figures/price-dist.png', dpi=300)

# %% [markdown]
# Some descriptive statistics of the price distribution:

# %%
df['price'].describe()
# Out:
# count     7818.000000
# mean      1583.984971
# std       1095.510351
# min          1.000000
# 25%        989.000000
# 50%       1299.000000
# 75%       1725.000000
# max      15900.000000
# Name: price, dtype: float64

# %% [markdown]
# Let's examine these outliers...

# %%
expensive = df[df['price'] > 12000]
expensive.head()
# Out:
#                                       address    price   bed  bath    area  \
# 1803                            39 Menlo Park  15900.0   2.0   2.0  1056.0
# 3730  10 br, 3 bath House - 725 Church Street  12530.0  10.0   3.0     NaN
# 5605   725 Church Street, Ann Arbor, MI 48104  12530.0  10.0   3.0     NaN
# 7822   723 Oakland Avenue Ann Arbor, MI 48104  12500.0   9.0   4.0     NaN
# 7823      814 Hill Street Ann Arbor, MI 48104  14250.0  10.0   3.0     NaN
#
#                           company  neighborhood  laundry  pets  parking  \
# 1803                         None          None      1.0   0.0      1.0
# 3730                         None          None      0.0   0.0      1.0
# 5605                         None          None      NaN   NaN      NaN
# 7822  Bartonbrook Properties, LLC  East Packard      1.0   0.0      1.0
# 7823  Bartonbrook Properties, LLC  East Packard      1.0   0.0      1.0
#
#                                 utilities property_type  year_built  \
# 1803                                   []          None         NaN
# 3730                                   []     apartment         NaN
# 5605                                   []         house         NaN
# 7822  [Recycling, Trash Removal included]         house         NaN
# 7823  [Recycling, Trash Removal included]         house         NaN
#
#                                             description  \
# 1803  39 MENLO PARK: 1992 Redman. 2-bedroom 2-bathro...
# 3730  (734) 663-8989 - 14 Bedroom House  - Available...
# 5605
# 7822  NEW RENOVATIONS!! 9 bedroom house located in a...
# 7823  Beautiful 12 bedroom/3 bath house, WITH UPDATE...
#
#                                                  images
# 1803  [https://images.craigslist.org/00303_5qJMibIEa...
# 3730                                                 []
# 5605  [https://s3.amazonaws.com/photos.rentlinx.com/...
# 7822                                                 []
# 7823                                                 []

# %% [markdown]
# ### Distribution of Price per Bedroom

# %%
df_ppb = df[df['price'].notnull() & (df['price'] > 0) & df['bed'].notnull() & (df['bed'] != 0)]
price = df_ppb.price.to_numpy()
bed = df_ppb.bed.to_numpy()
df_ppb['price per bed'] = pd.Series(np.divide(price, bed), index=df_ppb.index)
df_ppb.head()
# Out:
# C:\Users\ericy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 address   price  bed  bath    area company  \
# 0                  3050 Birch Hollow Dr  1095.0  2.0   1.0   876.0    None
# 1                          912 Rose Ave  2000.0  4.0   2.5  2000.0    None
# 2                                  None   695.0  3.0   2.0     NaN    None
# 3  1505 Natalie Lane near Kipling Drive  1385.0  1.0   1.0   800.0    None
# 4  1505 Natalie Lane near Kipling Drive  1185.0  1.0   1.0   800.0    None
#
#   neighborhood  laundry  pets  parking utilities property_type  year_built  \
# 0         None      1.0   1.0      1.0        []     apartment         NaN
# 1         None      1.0   1.0      1.0        []         house         NaN
# 2         None      1.0   0.0      1.0        []     apartment         NaN
# 3         None      1.0   1.0      1.0        []     apartment         NaN
# 4         None      1.0   1.0      1.0        []     apartment         NaN
#
#                                          description  \
# 0  This bedroom apartments includes:\n\n→ Contemp...
# 1  Stunning Ann Arbor home, perfect family house ...
# 2  AWESOME Affordable. This stunning 3 bedroom, 1...
# 3  Have you heard about our Stars & Stripes progr...
# 4  Have you heard about our Stars & Stripes progr...
#
#                                               images  price per bed
# 0  [https://images.craigslist.org/00S0S_8ZkasrSZ6...     547.500000
# 1  [https://images.craigslist.org/00Y0Y_4tey2xf24...     500.000000
# 2                                                 []     231.666667
# 3  [https://images.craigslist.org/00p0p_1PnkFaSsW...    1385.000000
# 4  [https://images.craigslist.org/00k0k_7n7PgfXF5...    1185.000000

# %%
sns.set(style='darkgrid')
plt.subplots(2, 1, figsize=(7,7))
plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
plt.subplot(2, 1, 1)
ax1 = sns.distplot(df_ppb['price per bed'], kde_kws={'bw':200, 'clip':[-1000, 8000]}, bins=32, color='#2ca0c2')
plt.ticklabel_format(style='plain', axis='y')
plt.subplot(2, 1, 2)
ax2 = sns.distplot(df_ppb['price per bed'], bins=32, color='#2ca0c2', kde=False, rug=True)
ax2.set_yscale('log')
plt.savefig('figures/price-by-bed-dist.png', dpi=300)

# %% [markdown]
# ### Joint Distribution of Price and Area
# This plot shows the joint (and marginal) distribution(s) of $\mathrm{log}$(price) and $\mathrm{log}$(area).

# %%
area = df[df['area'].notnull() & df['area'] != 0]['area']
df_plot = df.copy()
df_plot['log(area)'] = area.apply(lambda x: np.log10(x))
df_plot['log(price)'] = df_plot['price'].apply(lambda x: np.log10(x))

# ignore outliers! plot does NOT show long tail
sns.set(style='darkgrid')
g = sns.jointplot('log(price)', 'log(area)', df_plot, kind='scatter', alpha=0.8, s=0.1, color='#30bfbf')
g.ax_joint.set_ylim([2, 4])
g.ax_joint.set_xlim([2, 4])

for patch in g.ax_marg_x.patches:
    patch.set_facecolor('#2ca02c')

for patch in g.ax_marg_y.patches:
    patch.set_facecolor('#1f77b4') 

plt.savefig('figures/area-vs-price.png', dpi=300)

# %% [markdown]
# ### Correlation Heatmap
# The correlation heatmap below shows that intuitive trends are reflected in the data; for instance, we'd expect that price is highly correlated with the number of available bedrooms in a house or apartment. Note that many of the other correlations are relatively weak.

# %%
sns.set(style='white')
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.savefig('corr-heatmap.png', dpi=300)
corr
# Out:
#                price       bed      bath      area   laundry      pets  \
# price       1.000000  0.630296  0.340268  0.460245 -0.066057 -0.195342
# bed         0.630296  1.000000  0.666135  0.669075 -0.027155 -0.080173
# bath        0.340268  0.666135  1.000000  0.578336 -0.002040 -0.093690
# area        0.460245  0.669075  0.578336  1.000000 -0.056068 -0.123596
# laundry    -0.066057 -0.027155 -0.002040 -0.056068  1.000000  0.193587
# pets       -0.195342 -0.080173 -0.093690 -0.123596  0.193587  1.000000
# parking    -0.081144  0.076723  0.057643  0.066532  0.203173  0.320473
# year_built  0.253818 -0.237187  0.221848  0.245898  0.404787       NaN
#
#              parking  year_built
# price      -0.081144    0.253818
# bed         0.076723   -0.237187
# bath        0.057643    0.221848
# area        0.066532    0.245898
# laundry     0.203173    0.404787
# pets        0.320473         NaN
# parking     1.000000    0.175739
# year_built  0.175739    1.000000

# %% [markdown]
# ### Distribution of Price by Company
# We took the 10 most common companies and visualized the distribution of price by each of these companies.

# %%
df_plot = df.copy()
companies = df['company'].value_counts().iloc[:10].index.tolist()
print(df['company'].value_counts().iloc[:10])

df_plot = df_plot[df_plot['company'].isin(companies)]
sns.set(style='darkgrid')
plt.subplots(1,1, figsize=(20,4))
sns.boxplot(x='price', y='company', palette="husl", data=df_plot, fliersize=4, order=companies, saturation=0.8)
plt.xlim([-50, 6100])
plt.savefig('figures/boxplot-company.png', dpi=300)
# Out:
# Cabrio Properties                       318
# Campus Management, Inc.                 206
# PMSI                                    177
# Oxford Property Management              176
# J Keller Properties                     169
# The Hayman Company                      138
# Oakland Management Corp.                130
# Cappo Management & Deinco Properties    123
# Issa Properties                         112
# Village Green                           102
# Name: company, dtype: int64

# %% [markdown]
# ### Distribution of Price by Number of Bathrooms

# %%
df.plot(kind='scatter', x='bath', y='price', color='c', figsize=(8,8), alpha=0.3) # add jitter?

# %%
# Average cost
price_per_bath = df.groupby('bath')['price'].mean()
x1 = df['bath'].unique()
y1 = price_per_bath
x1 = x1[~np.isnan(x1)]

sns.set(style='darkgrid')
plt.figure(figsize=(10,6))
plt.scatter(x=x1, y=y1, color='limegreen')
plt.title('Scatterplot of Bathrooms vs Avg Cost')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Average Cost')
plt.tight_layout()

# %% [markdown]
# ### Distribution of Price by Pet Status

# %%
df.boxplot(column='price', by='pets', figsize=(12,6), vert=False, color='r')
plt.suptitle('') # removed default subtitle, it overlaps with title
plt.title('Boxplot of Price by Pet Status (y/n)')
plt.ylabel('Pet Status (1 = Yes)')
plt.xlabel('Price')
plt.tight_layout()

# %% [markdown]
# ### Distribution of Price by Parking Status

# %%
# PARKING STATUS
df.boxplot(column='price', by='parking', vert=False, figsize=(12,5), color='m')
plt.suptitle('') # removed default subtitle, it overlaps with title
plt.title('Boxplot of Price by Parking Status (y/n)')
plt.ylabel('Parking Status (1 = Yes)')
plt.xlabel('Price')
plt.tight_layout()

# %% [markdown]
# ### Distribution of Price by Laundry Status

# %%
df.boxplot(column='price', by='laundry', vert=False, figsize=(12,6), color='c')
plt.suptitle('') # removed default subtitle, it overlaps with title
plt.title('Boxplot of Price by Laundry Status (y/n)')
plt.ylabel('Laundry Status (1 = Yes)')
plt.xlabel('Price')
plt.tight_layout()

# %% [markdown]
# ### Marginal Distributions of Quantitative Variables

# %%
df_plot = df.drop(['laundry', 'parking', 'pets'], axis=1)
df_plot.hist(figsize=(25,5), layout=(1,5))
plt.tight_layout()

# %% [markdown]
# ### Average Price by Binary Variables

# %%
df_plot = df[['laundry', 'parking', 'pets']].dropna().astype(int)
laundry_price = df.groupby('laundry').mean()['price'].tolist()
parking_price = df.groupby('parking').mean()['price'].tolist()
pets_price = df.groupby('pets').mean()['price'].tolist()

r1 = [0, 2]
r2 = [0.4, 2.4]
r3 = [0.8, 2.8]

fig, ax = plt.subplots(figsize=(8,7))
plt.bar(x=r1, height=laundry_price, label='laundry', color='C0', width=0.35)
plt.bar(x=r2, height=parking_price, label='parking', color='C4', width=0.35)
plt.bar(x=r3, height=pets_price, label='pets', color='goldenrod', width=0.35)
ax.set_xticks([0.4, 2.4])
ax.set_xticklabels(('0', '1'))
ax.legend()

# %% [markdown]
# ### Distribution of Price by Property Type

# %%
# Property Type and their price mean and standard deviation 
# if there is >1 instance of that property type
prop_group = df[~df['property_type'].isin(['cottage/cabin', 'garden style', 'triplex'])].groupby('property_type')

# %%
# compute 95% confidence intervals
means = prop_group.mean().price.to_numpy()

# sort in descending order by price
indices = np.argsort(means)
error = prop_group.price.std().to_numpy()[indices][::-1]
df_prop = prop_group.mean().sort_values(by='price', ascending=False)
col = {i: df_prop.index.to_list()[i] for i in np.arange(14)}
df_prop = pd.concat([df_prop.reset_index(), pd.DataFrame(error, columns=['error'])], axis=1)
df_prop = df_prop.rename(index=col).drop('property_type', axis=1)

# %%
df_prop.price.plot(kind='bar', title='Property Types and Average Prices (with 95% Confidence Interval)', 
                  color='c', figsize=(10,6,), yerr=error, capsize=4)
plt.tight_layout()
plt.savefig('figures/Property vs Average Price', dpi=300)
