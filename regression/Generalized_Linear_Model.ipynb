# %%
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm

# %%
exog = pd.read_json('../data/model_data/X.json')
endog = np.exp(pd.read_json('../data/model_data/y.json', typ = 'series'))
data = pd.concat([endog.reset_index(drop=True), exog], axis = 1)
data = data.rename({0 : 'price'}, axis=1)

# %%
# y, X = dmatrices("price ~ bed + bath + area + \
#                  laundry + pets + parking + \
#                  lat + lon + distance_to_CCTC + distance_to_Pierpont + \
#                  distance_to_Stadium + distance_to_Union + distance_to_Ross + \
#                  distance_to_IM + distance_to_NCRB + distance_to_CCRB + \
#                  distance_to_UgLi + neighborhood + property_type + \
#                  neighborhood:parking", data) # interaction features go here!

# %%
y, X = dmatrices("price ~ bed + bath + area + \
                 laundry + pets + parking + \
                 distance_to_CCTC + distance_to_Pierpont + \
                 distance_to_Stadium + distance_to_Union + \
                 distance_to_UgLi + neighborhood + property_type + \
                 neighborhood:pets", data) # interaction features go here!

# %%
model = sm.GLM(y, X, family=sm.families.Gaussian())
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 4262
# Model:                            GLM   Df Residuals:                     4223
# Model Family:                Gaussian   Df Model:                           38
# Link Function:               identity   Scale:                      5.0102e+05
# Method:                          IRLS   Log-Likelihood:                -33996.
# Date:                Sat, 28 Mar 2020   Deviance:                   2.1158e+09
# Time:                        13:32:12   Pearson chi2:                 2.12e+09
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                     1526.8361    104.540     14.605      0.000    1321.941    1731.731
# neighborhood[T.Elbel]                         -599.1347     91.639     -6.538      0.000    -778.744    -419.525
# neighborhood[T.Germantown]                    -528.7147    102.952     -5.136      0.000    -730.498    -326.932
# neighborhood[T.North Burns Park]              -618.6828     96.509     -6.411      0.000    -807.836    -429.529
# neighborhood[T.North Ingalls]                 -235.7283    132.326     -1.781      0.075    -495.083      23.626
# neighborhood[T.Northside]                     -823.4414    172.671     -4.769      0.000   -1161.871    -485.012
# neighborhood[T.Old Fourth Ward]               -484.2009    102.168     -4.739      0.000    -684.447    -283.955
# neighborhood[T.Old West Side]                 -422.3717    174.879     -2.415      0.016    -765.128     -79.616
# neighborhood[T.Other Surrounding Areas]       -574.0603     88.359     -6.497      0.000    -747.240    -400.880
# neighborhood[T.Oxbridge]                      -222.9339    367.425     -0.607      0.544    -943.073     497.205
# neighborhood[T.South University]              -405.4061    121.634     -3.333      0.001    -643.805    -167.007
# neighborhood[T.Tappan]                        -532.1087     97.874     -5.437      0.000    -723.939    -340.278
# neighborhood[T.West Murfin]                  -1206.7144    182.828     -6.600      0.000   -1565.050    -848.379
# neighborhood[T.Yost]                          -168.6085     95.157     -1.772      0.076    -355.112      17.895
# property_type[T.house]                        -165.3470     35.888     -4.607      0.000    -235.687     -95.007
# bed                                           4147.5422    127.594     32.506      0.000    3897.463    4397.621
# bath                                         -1311.1821    194.572     -6.739      0.000   -1692.536    -929.829
# area                                          2963.9434    266.260     11.132      0.000    2442.083    3485.804
# laundry                                        102.8325     45.544      2.258      0.024      13.568     192.097
# pets                                             7.3888    143.595      0.051      0.959    -274.052     288.830
# neighborhood[T.Elbel]:pets                      53.6318    170.347      0.315      0.753    -280.241     387.505
# neighborhood[T.Germantown]:pets                 94.4709    169.449      0.558      0.577    -237.643     426.585
# neighborhood[T.North Burns Park]:pets         -424.6998    176.331     -2.409      0.016    -770.302     -79.098
# neighborhood[T.North Ingalls]:pets            -317.8886    188.877     -1.683      0.092    -688.081      52.304
# neighborhood[T.Northside]:pets                 130.0292    219.412      0.593      0.553    -300.010     560.069
# neighborhood[T.Old Fourth Ward]:pets          -206.7214    168.711     -1.225      0.220    -537.389     123.946
# neighborhood[T.Old West Side]:pets              36.9803    250.436      0.148      0.883    -453.866     527.826
# neighborhood[T.Other Surrounding Areas]:pets  -277.9145    146.597     -1.896      0.058    -565.240       9.411
# neighborhood[T.Oxbridge]:pets                 -188.0933    806.749     -0.233      0.816   -1769.292    1393.105
# neighborhood[T.South University]:pets          350.7689    286.398      1.225      0.221    -210.562     912.099
# neighborhood[T.Tappan]:pets                    109.1272    182.765      0.597      0.550    -249.086     467.341
# neighborhood[T.West Murfin]:pets              -220.0125    259.473     -0.848      0.396    -728.570     288.545
# neighborhood[T.Yost]:pets                     -831.7667    190.694     -4.362      0.000   -1205.520    -458.013
# parking                                       -271.5359     28.560     -9.508      0.000    -327.513    -215.559
# distance_to_CCTC                               341.3392   5073.580      0.067      0.946   -9602.695    1.03e+04
# distance_to_Pierpont                         -2748.9448    672.045     -4.090      0.000   -4066.129   -1431.760
# distance_to_Stadium                          -1679.2628    893.152     -1.880      0.060   -3429.808      71.283
# distance_to_Union                            -7748.9089   1925.342     -4.025      0.000   -1.15e+04   -3975.308
# distance_to_UgLi                              1.147e+04   4946.008      2.318      0.020    1772.562    2.12e+04
# ================================================================================================================
# """
