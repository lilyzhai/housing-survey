# %%
import pandas as pd
import numpy as np
from patsy import dmatrix, demo_data, ContrastMatrix, Poly
import statsmodels.api as sm

# %%
X = pd.read_json('../data/model_data/X.json')
y = pd.read_json('../data/model_data/y.json', typ = 'series')
data = pd.concat([y.reset_index(drop = True),X],axis = 1)
data = data.rename({0:'price'}, axis = 1)

# %%
y_ , X_ = dmatrices("price ~ bed + bath + area + laundry + pets + parking + lat + lon + distance_to_CCTC + distance_to_Pierpont + distance_to_Stadium + distance_to_Union + distance_to_Ross + distance_to_IM + distance_to_NCRB + distance_to_CCRB + distance_to_UgLi + neighborhood + property_type + neighborhood:parking",data)

# %%
model = sm.regression.linear_model.OLS(y_,X_)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                     85.89
# Date:                Sat, 28 Mar 2020   Prob (F-statistic):               0.00
# Time:                        13:43:49   Log-Likelihood:                -2397.8
# No. Observations:                4266   AIC:                             4884.
# Df Residuals:                    4222   BIC:                             5163.
# Df Model:                          43
# Covariance Type:            nonrobust
# ...
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# ...
