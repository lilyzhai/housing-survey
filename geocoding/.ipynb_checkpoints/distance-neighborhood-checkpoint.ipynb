# %%
import math
import pandas as pd

# %%
## returns straight-line (Euclidean) distance in km
def distance(address, landmark):
    lat1, lon1 = address
    lat2, lon2 = landmark
    p = 0.017453292519943295;    # Math.PI / 180
    a = 0.5 - math.cos((lat2 - lat1) * p) / 2 + math.cos(lat1 * p) * math.cos(lat2 * p) * (1 - math.cos((lon2 - lon1) * p)) / 2;

    return 12742 * math.asin(math.sqrt(a)) # 2 * R; R = 6371 km

# %%
# test function -- CCTC to Pierpont
distance((42.278165, -83.734749), (42.291151, -83.717377))
# Out:
# 2.031583762765907

# %%
# load data
df = pd.read_csv('../data/geocoded_data/coords.csv', lineterminator='\n').drop('Unnamed: 0', axis=1).rename(columns={'latitude': 'lat', 'longitude': 'lon'})

# %%
# drop entries with no price or coordinates
df = df[df['address'].notnull() & df['lat'].notnull()]
df.head()
# Out:
#                                 address   price  bed  bath  area company  \
# 0                  3050 Birch Hollow Dr  1095.0  2.0   1.0   876     NaN
# 1                          912 Rose Ave  2000.0  4.0   2.5  2000     NaN
# 3  1505 Natalie Lane near Kipling Drive  1385.0  1.0   1.0   800     NaN
# 4  1505 Natalie Lane near Kipling Drive  1185.0  1.0   1.0   800     NaN
# 6  1505 Natalie Lane near Kipling Drive  1375.0  1.0   1.0   800     NaN
#
#   neighborhood  laundry  pets  parking utilities property_type  year_built  \
# 0          NaN      1.0   1.0      1.0        []     apartment         NaN
# 1          NaN      1.0   1.0      1.0        []         house         NaN
# 3          NaN      1.0   1.0      1.0        []     apartment         NaN
# 4          NaN      1.0   1.0      1.0        []     apartment         NaN
# 6          NaN      1.0   1.0      0.0        []     apartment         NaN
#
#                                          description  \
# 0  This bedroom apartments includes:\n\n→ Contemp...
# 1  Stunning Ann Arbor home, perfect family house ...
# 3  Have you heard about our Stars & Stripes progr...
# 4  Have you heard about our Stars & Stripes progr...
# 6  Have you heard about our Stars & Stripes progr...
#
#                                               images     updated_addresses  \
# 0  ['https://images.craigslist.org/00S0S_8ZkasrSZ...  3050 birch hollow dr
# 1  ['https://images.craigslist.org/00Y0Y_4tey2xf2...          912 rose ave
# 3  ['https://images.craigslist.org/00p0p_1PnkFaSs...    1505 natalie lane
# 4  ['https://images.craigslist.org/00k0k_7n7PgfXF...    1505 natalie lane
# 6  ['https://images.craigslist.org/00s0s_fSIY5lG9...    1505 natalie lane
#
#                                        location_data  \
# 0  [Location(3050, Birch Hollow Drive, Ann Arbor,...
# 1  [Location(912, Rose Avenue, Lower Burns Park, ...
# 3  [Location(1505, Natalie Lane, Ann Arbor, Washt...
# 4  [Location(1505, Natalie Lane, Ann Arbor, Washt...
# 6  [Location(1505, Natalie Lane, Ann Arbor, Washt...
#
#                                             raw_data        lat        lon
# 0  [[{'place_id': 254613549, 'licence': 'Data © O...  42.238978 -83.718505
# 1  [[{'place_id': 254599966, 'licence': 'Data © O...  42.262519 -83.738165
# 3  [[{'place_id': 254598836, 'licence': 'Data © O...  42.293951 -83.683362
# 4  [[{'place_id': 254598836, 'licence': 'Data © O...  42.293951 -83.683362
# 6  [[{'place_id': 254598836, 'licence': 'Data © O...  42.293951 -83.683362

# %%
landmarks = ['CCTC', 'Pierpont', 'Stadium', 'Union', 'Ross', 'IM', 'NCRB', 'CCRB', 'UgLi']
landmark_coords = [(42.278165, -83.734749), 
                   (42.291151, -83.717377), 
                   (42.265865, -83.748684),
                   (42.275177, -83.741517),
                   (42.278046, -83.738220),
                   (42.269382, -83.749068),
                   (42.295156, -83.714627),
                   (42.281104, -83.733603),
                   (42.275654, -83.737176)]

for landmark, coord in zip(landmarks, landmark_coords):
    s = f'distance_to_{landmark}'
    addresses = zip(df.lat, df.lon)
    dist = []
    for address in addresses:
        dist.append(distance(address, landmark_coords))
    df[f'distance_to_{landmark}'] = dist
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-b2b3100cc5cb> in <module>
#      15     dist = []
#      16     for address in addresses:
# ---> 17         dist.append(distance(address, landmark_coords))
#      18     df[f'distance_to_{landmark}'] = dist
#
# <ipython-input-2-d1291a36fb01> in distance(address, landmark)
#       2 def distance(address, landmark):
#       3     lat1, lon1 = address
# ----> 4     lat2, lon2 = landmark
#       5     p = 0.017453292519943295;    # Math.PI / 180
#       6     a = 0.5 - math.cos((lat2 - lat1) * p) / 2 + math.cos(lat1 * p) * math.cos(lat2 * p) * (1 - math.cos((lon2 - lon1) * p)) / 2;
#
# ValueError: too many values to unpack (expected 2)

# %%
df.head()

# %%
# save new data
df.to_json('../data/model_data/data.json')
