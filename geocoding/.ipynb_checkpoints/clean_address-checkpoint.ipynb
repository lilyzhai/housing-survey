# %%
import pandas as pd
import re

df = pd.read_json('../data/aggregated.json')
addresses = df.address
idx, dirty = [], []
for i, address in enumerate(addresses.values):
    if address == None:
        pass
    elif not re.search('^\d', address):
        idx.append(i)
        dirty.append(address)
        
dirty
# Out:
# ['Pauline near Stadium',
#  'Pauline Blvd',
#  'Pauline near Stadium',
#  'Pauline near Stadium',
#  'Pauline near Stadium',
#  'Sylvan near Packard',
#  'Packard near Dewey',
#  'Prospect near E. University',
#  'E. Ann St. near N. State St.',
#  'E. Ann St. near N. State St.',
#  'E. Ann St. near N. State St.',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Dunlavy Lane near Mast and Strawberry Lake Road',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Twin Lakes Drive near Golfside Road',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'Twin Lakes Drive near Golfside Road',
#  'Roundtree Blvd near Ellsworth St',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Virginia Ave',
#  'pauline blvd',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'Latson near Grand River',
#  'E Prospect near Forest',
#  'E Prospect near Forest',
#  'E Clark near Prospect',
#  'W Liberty near Stadium',
#  'Roundtree Blvd. near Ellsworth',
#  'Twin Lakes Drive near Golfside Road',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'pauline blvd',
#  'Briarcrest near Main',
#  'W Liberty near Stadium',
#  'W Liberty near Stadium',
#  'pauline blvd',
#  'pauline blvd',
#  'Schooner Cove Blvd. near Huron River Drive',
#  'Woodridge Way near Twin Lakes Drive',
#  'S. Division near Packard',
#  'Sylvan near Packard',
#  'Prospect near E. University',
#  'Olde Engligh Circle',
#  'Liberty Pointe Drive',
#  'Pepperidge Trail',
#  'Dufree',
#  'Oak Pointe',
#  'Academy',
#  'Birch Hollow Drive near Stone School Road',
#  'Birch Hollow Drive near Stone School Road',
#  'Birch Hollow Drive near Stone School Road',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Leslie Circle near Huron Parkway',
#  'Twin Lakes Drive near Golfside Road',
#  'South Main Street near Ann Arbor Saline',
#  'Leslie Circle near Huron Parkway',
#  'Roundtree Blvd near Ellsworth',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'Schooner Cove Blvd. near Huron River Drive',
#  'Woodridge Way near Golfside',
#  'Birch Hollow Drive near Stone School Road',
#  'Stadium Blvd near Pauline Blvd',
#  'pauline blvd',
#  'W Liberty near Stadium',
#  'Emmet near Perrin',
#  'Emmet near Perrin',
#  'Latson near Grand River',
#  'W Liberty near Stadium',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'pauline blvd',
#  'pauline blvd',
#  'Roundtree Blvd near Ellsworth St',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'Birch Hollow Drive near Stone School Road',
#  'W Liberty near Stadium',
#  'South Main Street near Ann Arbor Saline',
#  'Birch Hollow Drive near Stone School Road',
#  'Roundtree Blvd near Ellsworth Rd',
#  'W Liberty near Stadium',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'E Prospect near Forest',
#  'E Prospect near Forest',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'pauline blvd',
#  'pauline blvd',
#  'Packard St near State St',
#  'Roundtree Blvd near Ellsworth',
#  'pauline',
#  'packard near Carpenter',
#  'Main near Briarcrest',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'Roundtree Blvd. near Ellsworth',
#  'Roundtree Blvd near Ellsworth Rd',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Blvd. near Huron River Drive',
#  's main street near ann arbor saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  's main street near ann arbor saline',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'pauline blvd',
#  'virginia near fair',
#  'pauline blvd',
#  'pauline blvd',
#  'Birch Hollow Drive near Stone School Road',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Woodridge Way near Twin Lakes Drive',
#  'Burbank Drive near Green Road',
#  'middle court near Wilkinson Street',
#  'Roundtree Blvd near Ellsworth Rd',
#  'Stadium Blvd near Pauline Blvd',
#  's main street near ann arbor saline',
#  'pauline blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'Leslie Circle near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  's main street near ann arbor saline',
#  'Birch Hollow Drive near Stone School Road',
#  'Leslie Circle near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'Birch Hollow Drive near Stone School Road',
#  'Schooner Cove Blvd near Huron River Drive',
#  'Briarcrest near main',
#  'Briarcrest near Main',
#  'Birch Hollow Drive near Stone School Road',
#  'Lancashire Drive near Huron Parkway',
#  'W Liberty near Stadium',
#  'Birch Hollow Drive near Stone School Road',
#  'Roundtree Blvd near Ellsworth Rd',
#  'PAULINE BLVD',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Main near Briarcrest',
#  'Morgan near State',
#  'S Forest Ave near Wells',
#  'North Adams near Olive',
#  'Cross near Ballard',
#  'Washtenaw near Washington',
#  'Michigan near Wiard',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Nixon rd near Plymouth rd',
#  'Golden Ave',
#  'Lake Haven Dr',
#  'Cloverly Ln',
#  'W Liberty near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Meadow Grove trail near Oak Valley Dr',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'W Liberty near Stadium',
#  'Lancashire Drive near Huron Parkway',
#  'Roundtree Blvd near Ellsworth Rd',
#  'Twin Lakes Drive near Golfside Road',
#  'Roundtree Blvd near Ellsworth',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'Schooner Cove Blvd. near Huron River Drive',
#  'Lancashire Drive near Huron Parkway',
#  'Scenic Way near Besants',
#  'Leslie Circle near Huron Parkway',
#  'Leslie Circle near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Knotty pine trail near pinecroft',
#  'Third Street near Madison',
#  'Third Street near West Jefferson',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'W Liberty near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'RD near Green/Nixon',
#  'Highlander Way near Yorkshire',
#  'Schooner Cove Blvd near Huron River Drive',
#  'W Liberty near Stadium',
#  'Portside Dr. near Pontiac Trail',
#  'W Liberty near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Ecorse near Harris',
#  'W Liberty near Stadium',
#  'Lancashire Drive near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'Latson near Grand River',
#  'Birch Hollow Drive near Stone School Road',
#  'Schooner Cove Blvd near Huron River Road',
#  'W Liberty near Stadium',
#  'Golfside Rd. near Washtenaw Rd.',
#  'commerce blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Grandview',
#  'Textile rd',
#  'Island drive',
#  'Foley near Harris',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline Road',
#  'Abbott Ave near Burwood',
#  'Latson near Grand River',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline Road',
#  'Pauline near Stadium',
#  'Pauline near Stadium',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline Road',
#  'whitmore lake road near maltby',
#  'W Liberty near Stadium',
#  'Ann Arbor Saline Rd near South Main Street',
#  'forest near prospect',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow Dr near Stone School Rd',
#  'Birch Hollow Dr near Stone School Rd',
#  'Stadium Blvd near Pauline Blvd',
#  'Lancashire Drive near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'W Liberty near Stadium',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Leslie Circle near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow Dr near Stone School Rd',
#  'Birch Hollow Dr near Stone School Rd',
#  'Birch Hollow Dr near Stone School Rd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Lancashire Drive near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'W Liberty near Stadium',
#  'fountain near summit',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Blvd near Huron River Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow near Stone School Road',
#  'Pauline near Stadium',
#  'Pauline near Stadium',
#  'Plymouth Road near Upland',
#  'Maiden Ln near Nielsen Ct',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow near Stone School Road',
#  'Maiden Ln near Nielsen Ct',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'South Main Street near Ann Arbor Saline',
#  'Golfside near Washtenaw',
#  'Schooner Cove Blvd near Huron River Road',
#  'Birch Hollow near Stone School Road',
#  'Birch Hollow near Stone School Road',
#  'W Liberty near Stadium',
#  'Lancashire Drive near Huron Parkway',
#  'Twin Lakes Drive near Golfside Road',
#  'Birch Hollow near Stone School Road',
#  'Leslie Circle near Huron Parkway',
#  'W Liberty near Stadium',
#  'Schooner Cove Boulevard near Huron River Road',
#  'Pauline near Stadium',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow near Stone School Road',
#  'Lancashire Drive near Huron Parkway',
#  'Golfside near Washtenaw',
#  'Twin Lakes Drive near Golfside Road',
#  'W Liberty near Stadium',
#  'South Main Street near Ann Arbor Saline',
#  'Lancashire Drive near Huron Parkway',
#  'W Liberty near Stadium',
#  'Twin Lakes Drive near Golfside Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'S main street near Ann Arbor Saline',
#  'Catherine Street near State Street',
#  'Twin Lakes Drive near Golfside Road',
#  'Twin Lakes Drive near Golfside Road',
#  'Twin Lakes Drive near Golfside Road',
#  'Lancashire Drive near Huron Parkway',
#  'Twin Lakes Drive near Golfside Road',
#  'Liberty near State',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'packard near wells',
#  'Leslie Circle near Huron Parkway',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Glencoe hills dr.',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Leslie Circle near Huron Parkway',
#  'Twin Lakes Drive near Golfside Road',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Twin Lakes Drive near Golfside Road',
#  'Leslie Circle near Huron Parkway',
#  'S main street near Ann Arbor Saline',
#  'Twin Lakes Drive near Golfside Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Blvd near Huron River Drive',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Golfside Road near Twin Lakes Drive',
#  'Pauline near Stadium',
#  'Twin Lakes Drive near Golfside Road',
#  'Schooner Cove Blvd near Huron River Drive',
#  'Stadium Blvd near Pauline Blvd',
#  'Harriet',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'Leslie Circle near Huron Parkway',
#  'Twin Lakes Drive near Golfside Road',
#  'Golfside near Washtenaw',
#  'South Main Street near Ann Arbor Saline Road',
#  'Twin Lakes Drive near Golfside Road',
#  'Pauline Blvd near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Blvd near Huron River Road',
#  'South Main Street near Ann Arbor Saline',
#  'Pauline Blvd near Stadium',
#  'Leslie Circle near Huron Parkway',
#  'South Main Street near Ann Arbor Saline Road',
#  'South Main Street near Ann Arbor Saline',
#  'Schooner Cove Blvd near Huron River Road',
#  'Pauline near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline',
#  'Pepperidge Trail',
#  'Kenicott',
#  'Dufree',
#  'Town Commons',
#  'Leith',
#  'Kellogg St near Long Shore Drive',
#  'Pauline Blvd near Stadium',
#  'Leslie Circle near Huron Parkway',
#  'Golfside near Washtenaw',
#  'Golfside near Washtenaw',
#  'South Main Street near Ann Arbor Saline',
#  'WEST DELHI ROAD near Dexter-Ann Arbor',
#  'Emmet near Perrin',
#  'Emmet near Perrin',
#  'downing near champagne',
#  'Dunlavy Lane near Mast and Strawberry Lake Road',
#  'E. Ann St. near N. State St.',
#  'E. Ann St. near N. State St.',
#  'E. Ann St. near N. State St.',
#  'South Main Streeta near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Boulevard near Huron River Road',
#  'Twin Lakes Drive near Golfside Road',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Twin Lakes Dr near Golfside Rd',
#  'Leslie Circle near Huron Parkway',
#  'South Main Street near Ann Arbor Saline',
#  'Twin Lakes Drive near Golfside Road',
#  'Schooner Cove Blvd near Huron River Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Birch Hollow Dr',
#  'South Main Street near Ann Arbor Saline',
#  'Pauline near Stadium',
#  'Schooner Cove Boulevard near Huron River Road',
#  'Stadium Blvd near Pauline Blvd',
#  'wellsville hwy near mitchell',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Latson near Grand River',
#  'Pauline near Stadium',
#  'Pauline near Stadium',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Stadium Blvd near Pauline Blvd',
#  'Leslie Circle near Huron Parkway',
#  'Birch Hollow Drive near Stone School Road',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline',
#  'Pauline near Stadium',
#  'Twin Lakes Dr. near Golfside Rd.',
#  'Twin Lakes Dr near Golfside Rd.',
#  'Baker near Shield',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Dewey near Packard',
#  'Dexter near Packard',
#  'Southlawn near Dexter',
#  'Latson near Grand River',
#  'Twin Lakes Drive near Golfside Road',
#  'Clark Rd near Laforge',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'Latson near Grand River',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Jackson near Stadium',
#  'dellwood dr near hollywood dr',
#  'Latson near Grand River',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'Golfside near Washtenaw',
#  'Stadium Blvd near Pauline Blvd',
#  'lohr near ann arbor saline',
#  'Golfside Road near Twin Lakes Drive',
#  'Golfside Lake near Twin Lake',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'fieldcrest',
#  'fieldcrest',
#  'Fieldcrest',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'Stadium Blvd near Pauline Blvd',
#  'Golfside near Washtenaw',
#  'Golfside near Washtenaw',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Blvd near Huron River Drive',
#  'Brookline near Gordon',
#  's 1st near w William',
#  'Charlton near Pleasent',
#  'Lawrence near State',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'Latson near Grand River',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'Latson near Grand River',
#  'Golfside near Washtenaw',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Michigan Avenue near Jackson Street',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Latson near Grand River',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes near Golfside',
#  'Stadium Blvd near Pauline Blvd',
#  'Pauline near Stadium',
#  'Golfside near Washtenaw',
#  'Golfside near Washtenaw',
#  'Twin Lakes Drive near Golfside Road',
#  'South Main Street near Ann Arbor Saline',
#  'Twin Lakes Drive near Golfside Road',
#  'Calhoun near Diversey',
#  'Pauline near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'Southlawn near Dexter',
#  'Dexter near Packard',
#  'bolgos cir',
#  'Madison Street',
#  'Third near Liberty',
#  'Dunlavy Lane near Mast and Strawberry Lake Road',
#  'Little Lake Drive',
#  'South Main Street near Ann Arbor Saline',
#  'Latson near Grand River',
#  'Michigan ave',
#  'Stadium Blvd near Pauline Blvd',
#  'Schooner Cove Boulevard near Huron River Drive',
#  'Twin Lakes Drive near Golfside Road',
#  'N.Normal #B3',
#  'Stadium Blvd near Pauline Blvd',
#  'Stadium Blvd near Pauline Blvd',
#  'Thompson St near Washington St',
#  'Stadium Blvd near Pauline Blvd',
#  'Twin Lakes Drive near Golfside Road',
#  'byron road near w. highlan rd',
#  'Wilmot near Washtenaw',
#  'Dunlavy Lane near Mast and Strawberry Lake Road',
#  'Latson near Grand River',
#  'Latson near Grand River',
#  'Pauline near Stadium',
#  'Mosley near Main',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium Blvd near Pauline Blvd',
#  'Pauline near Stadium',
#  'washtenaw near ballard',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline',
#  'washtenaw near ballard',
#  'Townsquare Blvd near Old US 23',
#  'Pauline near Stadium',
#  'Stadium Blvd near Pauline Blvd',
#  'South Main Street near Ann Arbor Saline Road',
#  'Stadium Blvd near Pauline Blvd',
#  'Latson near Grand River',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Stadium Blvd near Pauline Blvd',
#  'S Revena Blvd near Huron',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Stadium Place near Pauline',
#  'Glencoe Hills Dr near Glencoe Hills Dr',
#  'Ann Arbor Saline Rd near South Main Street',
#  'South Main Street near Ann Arbor Saline Road',
#  'Emmet near Ballard',
#  'collinson near 9 mile',
#  'South Main Street near Ann Arbor Saline',
#  'South Main Street near Ann Arbor Saline',
#  'Ann Arbor Saline Rd near South Main Street',
#  'South Main Street near Ann Arbor Saline',
#  'Twin Lakes Drive near Golfside Road',
#  'South Main Street near Ann Arbor Saline',
#  'Stadium near Pauline',
#  'Stadium near Pauline',
#  'Twin Lakes Drive near Golfside Road',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Twin Lakes Drive near Golfside Road',
#  'Stadium near Pauline',
#  'Stadium near Pauline',
#  'Golfside near Washtenaw',
#  'Golfside near Washtenaw',
#  'Ann Arbor Saline Rd near South Main Street',
#  'Esch near Page',
#  'Twin Lakes Drive near Golfside Road',
#  'Abbott near Burwood',
#  'Abbott near Burwood',
#  'Stadium near Pauline',
#  'Stadium near Pauline',
#  'W Liberty St near Stadium',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'City Place Ann Arbor',
#  'Studio, 1 bath Apartment - 1352 Wilmot Ct #1',
#  'Studio, 1 bath House - 804 Monroe St Apt #3',
#  'Pheasant Run Apartments',
#  'Pheasant Run Apartments',
#  'Pheasant Run Apartments',
#  'Pheasant Run Apartments',
#  'Studio, 1 bath House - 1309 S State St Unit 4',
#  'Arbor Apartments',
#  'Studio, 1 bath Duplex - 320 S. Division 12',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Island Drive',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Cambridge Club Apartment Homes',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Ponds at Georgetown Apartments',
#  'Centerra Pointe',
#  'Centerra Pointe',
#  'Centerra Pointe',
#  'Centerra Pointe',
#  'Centerra Pointe',
#  'Centerra Pointe',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Woodbury Gardens Apartments & Townhomes',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Spice Tree',
#  'Studio, 1 bath House - 804 Monroe St Apt B',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Orion MainStreet',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Lakestone Apartments',
#  'Second Street Apartment',
#  'The Sans Souci',
#  'The Sans Souci',
#  'The Sans Souci',
#  'The Sans Souci',
#  'The Sans Souci',
#  'The Sans Souci',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'GreenBrier',
#  'Studio, 1 bath House - 226 Packard 2',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Owl Creek',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Ivanhoe Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Charlton Apartments',
#  'Arbor Club Apartments',
#  'Arbor Club Apartments',
#  'Arbor Club Apartments',
#  'Arbor Club Apartments',
#  'Arbor Club Apartments',
#  'Arbor Club Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Arbor Landings Apartments',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Wyndham Hill',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Oakcliff Apartments',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Orion NorthStar',
#  'Studio, 1 bath Apartment - 311 Thompson St #5',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  'The Haven of Ann Arbor',
#  ...]
